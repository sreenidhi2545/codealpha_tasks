# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenidhi2545/Unemployment-Task2/blob/main/Unemployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()

filename = list(uploaded.keys())[0]
df = pd.read_csv(io.BytesIO(uploaded[filename]))

df.columns = df.columns.str.strip()
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

plt.figure(figsize=(15, 7))
sns.lineplot(data=df, x='Date', y='Estimated Unemployment Rate (%)', hue='Region')
plt.title('Unemployment Rate Over Time by Region', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.show()


latest_date = df['Date'].max()
latest_df = df[df['Date'] == latest_date]

plt.figure(figsize=(12, 8))
sns.barplot(data=latest_df, y='Region', x='Estimated Unemployment Rate (%)', hue='Area')
plt.title(f'Unemployment Rate by Region and Area ({latest_date.date()})', fontsize=15)
plt.xlabel('Unemployment Rate (%)')
plt.ylabel('Region')
plt.grid(True, axis='x', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-bf636f4f-83e2-4e45-a965-26ecd2823339" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf636f4f-83e2-4e45-a965-26ecd2823339">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
